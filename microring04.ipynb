# %%
import numpy as np
import matplotlib.pyplot as plt

import tidy3d as td
import tidy3d.web as web
from tidy3d.plugins.mode import ModeSolver

# %% [markdown]
# # Simulation Setup
# Simulation of a microring resonator demultiplexer / filter.
# Consists of a ring resonator in the center, a bottom waveguide containing a mode source and the through port, and a top waveguide containing the drop port.

# %%
# ring resonator device parameters
wg_height = 0.220 # height of the waveguide (um)
wg_width = 0.440 # width of the waveguide (um)
radius1 = 2.2 # radius of the ring resonator (um)
radius2 = 2.1
radius3 = 2.0
radius4 = 1.9
gap = 0.140 # gap between the ring resonator and the straight waveguides (um)

# %%
# permittivity of the waveguide and substrate at 1550nm
si_eps = 12.085
sio2_eps = 2.0852

# wavelength (in um) and frequency (in Hz)
lambda_range = (1.5, 1.6) # corresponding to the C-band (1.53 to 1.565)
lambda0 = np.sum(lambda_range)/2
freq_range = (td.C_0 / lambda_range[1], td.C_0 / lambda_range[0])
freq0 = td.C_0 / lambda0
freqw = freq_range[1] - freq_range[0]

# frequencies and wavelengths of monitor
Nfreq = 1024
monitor_lambdas = np.linspace(lambda_range[0], lambda_range[1], Nfreq)
monitor_freqs = np.linspace(freq_range[0], freq_range[1], Nfreq)

# spacing between the waveguide and the PML
spacing = 0.8 #um

# simulation domain and total run time
sim_size = (2*(spacing + radius1 + gap + wg_width + spacing/2 + radius3 + gap + wg_width), 2*(spacing + radius1 + radius2 + gap + 1.5*wg_width), wg_height + 2*spacing)
run_time = 8888/freq0
print("Run Time =", run_time)

# grid specification
grid_spec = td.GridSpec.auto(min_steps_per_wvl = 20, wavelength = lambda0)

# waveguide, substrate, and air material
mat_wg = td.Medium(
    permittivity = si_eps,
    name = "silicon",
)
mat_substrate = td.Medium(
    permittivity = sio2_eps,
    name = "silica",
)

# ring resonator 1
ring1_center = -sim_size[0]/2 + spacing + wg_width/2 + radius1

ring1_outer = td.Structure(
    geometry = td.Cylinder(
        center = [ring1_center, sim_size[1]/2 - spacing - radius1 - wg_width/2, 0],
        radius = radius1 + wg_width/2,
        length = wg_height,
    ),
    medium = mat_wg,
    name = "Outer Ring 1",
)
ring1_inner = td.Structure(
    geometry = td.Cylinder(
        center = [ring1_center, sim_size[1]/2 - spacing - radius1 - wg_width/2, 0],
        radius = radius1 - wg_width/2,
        length = wg_height,
    ),
    medium = mat_substrate,
    name = "Inner Ring 1",
)

# ring resonator 2
ring2_center = -sim_size[0]/2 + spacing + wg_width/2 + radius2

ring2_outer = td.Structure(
    geometry = td.Cylinder(
        center = [ring2_center, -sim_size[1]/2 + spacing + radius2 + wg_width/2, 0],
        radius = radius2 + wg_width/2,
        length = wg_height,
    ),
    medium = mat_wg,
    name = "Outer Ring 2",
)
ring2_inner = td.Structure(
    geometry = td.Cylinder(
        center = [ring2_center, -sim_size[1]/2 + spacing + radius2 + wg_width/2, 0],
        radius = radius2 - wg_width/2,
        length = wg_height,
    ),
    medium = mat_substrate,
    name = "Inner Ring 2",
)


# ring resonator 3
ring3_center = ring1_center + radius1 + 2*wg_width + gap + spacing + radius3

ring3_outer = td.Structure(
    geometry = td.Cylinder(
        center = [ring3_center, sim_size[1]/2 - spacing - 2*(radius1 - radius3) - radius3 - wg_width/2, 0],
        radius = radius3 + wg_width/2,
        length = wg_height,
    ),
    medium = mat_wg,
    name = "Outer Ring 3",
)
ring3_inner = td.Structure(
    geometry = td.Cylinder(
        center = [ring3_center, sim_size[1]/2 - spacing - 2*(radius1 - radius3) - radius3 - wg_width/2, 0],
        radius = radius3 - wg_width/2,
        length = wg_height,
    ),
    medium = mat_substrate,
    name = "Inner Ring 3",
)

# ring resonator 4
ring4_center = ring2_center + radius2 + 2*wg_width + gap + spacing + radius4

ring4_outer = td.Structure(
    geometry = td.Cylinder(
        center = [ring4_center, -sim_size[1]/2 + spacing + 2*(radius2 - radius4) + radius4 + wg_width/2, 0],
        radius = radius4 + wg_width/2,
        length = wg_height,
    ),
    medium = mat_wg,
    name = "Outer Ring 4",
)
ring4_inner = td.Structure(
    geometry = td.Cylinder(
        center = [ring4_center, -sim_size[1]/2 + spacing + 2*(radius2 - radius4) + radius4 + wg_width/2, 0],
        radius = radius4 - wg_width/2,
        length = wg_height,
    ),
    medium = mat_substrate,
    name = "Inner Ring 4",
)

# input and output waveguides
waveguide_output1 = td.Structure(
    geometry = td.Box(
        center = [-sim_size[0]/2 + spacing + 2*radius1 + 1.5*wg_width + gap, sim_size[1]/2, 0],
        size = [wg_width, 4 * radius1, wg_height],
    ),
    medium = mat_wg,
    name = "Output 1 Waveguide"
)
waveguide_output2 = td.Structure(
    geometry = td.Box(
        center = [-sim_size[0]/2 + spacing + 2*radius2 + 1.5*wg_width + gap, -sim_size[1]/2, 0],
        size = [wg_width, 4 * radius2, wg_height],
    ),
    medium = mat_wg,
    name = "Output 2 Waveguide"
)
waveguide_output3 = td.Structure(
    geometry = td.Box(
        center = [ring1_center + radius1 + 3*wg_width + 2*gap + spacing + 2*radius3, sim_size[1]/2, 0],
        size = [wg_width, 4 * radius1, wg_height],
    ),
    medium = mat_wg,
    name = "Output 3 Waveguide"
)
waveguide_output4 = td.Structure(
    geometry = td.Box(
        center = [ring2_center + radius2 + 3*wg_width + 2*gap + spacing + 2*radius4, -sim_size[1]/2, 0],
        size = [wg_width, 4 * radius2, wg_height],
    ),
    medium = mat_wg,
    name = "Output 4 Waveguide"
)
waveguide_input = td.Structure(
    geometry = td.Box(
        center = [0, sim_size[1]/2 - spacing - 1.5*wg_width - 2*radius1 - gap, 0],
        size = [td.inf, wg_width, wg_height],
    ),
    medium = mat_wg,
    name = "Input Waveguide"
)

# xy-plane frequency-domain field monitor at central frequency
field_mnt = td.FieldMonitor(
    center = [0,0,0],
    size = [np.inf, np.inf, 0],
    freqs = [193.6465e12, 193.9640e12, 193.3046e12, 194.2448e12],
    name = "Field",
)

# through port flux monitor
flux_mnt_through = td.FluxMonitor(
    center = [sim_size[0]/2 - spacing, sim_size[1]/2 - spacing - 1.5*wg_width - 2*radius1 - gap, 0],
    size = [0, 4 * wg_width, 6 * wg_height],
    freqs = monitor_freqs,
    name = "Flux Monitor (Through Port)"
)

# drop port flux monitors
flux_mnt_drop1 = td.FluxMonitor(
    center = [-sim_size[0]/2 + spacing + 2*radius1 + 1.5*wg_width + gap, sim_size[1]/2 - spacing, 0],
    size = [4 * wg_width, 0, 6 * wg_height],
    freqs = monitor_freqs,
    name = "Flux Monitor (Drop Port 1)",
    normal_dir = "+"
)

flux_mnt_drop2 = td.FluxMonitor(
    center = [-sim_size[0]/2 + spacing + 2*radius2 + 1.5*wg_width + gap, -sim_size[1]/2 + spacing, 0],
    size = [4 * wg_width, 0, 6 * wg_height],
    freqs = monitor_freqs,
    name = "Flux Monitor (Drop Port 2)",
    normal_dir = "-"
)

flux_mnt_drop3 = td.FluxMonitor(
    center = [ring1_center + radius1 + 3*wg_width + 2*gap + spacing + 2*radius3, sim_size[1]/2 - spacing, 0],
    size = [4 * wg_width, 0, 6 * wg_height],
    freqs = monitor_freqs,
    name = "Flux Monitor (Drop Port 3)",
    normal_dir = "+"
)

flux_mnt_drop4 = td.FluxMonitor(
    center = [ring2_center + radius2 + 3*wg_width + 2*gap + spacing + 2*radius4, -sim_size[1]/2 + spacing, 0],
    size = [4 * wg_width, 0, 6 * wg_height],
    freqs = monitor_freqs,
    name = "Flux Monitor (Drop Port 4)",
    normal_dir = "-"
)

# simulation
sim = td.Simulation(
    size = sim_size,
    grid_spec = grid_spec,
    symmetry = [0, 0, 1],
    structures = [ring1_outer, ring1_inner, ring2_outer, ring2_inner, ring3_outer, ring3_inner, ring4_outer, ring4_inner, waveguide_output1, waveguide_output2, waveguide_output3, waveguide_output4, waveguide_input],
    medium = mat_substrate,
    sources = [],
    monitors = [field_mnt, flux_mnt_through, flux_mnt_drop1, flux_mnt_drop2, flux_mnt_drop3, flux_mnt_drop4],
    run_time = run_time,
    shutoff = 1e-6,
    boundary_spec = td.BoundarySpec.all_sides(boundary = td.PML())
)
# Out:
# Run Time = 4.595312401087822e-11

# %% [markdown]
# # Source Setup
# Define a mode source that launches the TE0 mode into the input waveguide.

# %%
# position and size of source plane
source_plane = td.Box(
    center = (-sim_size[0]/2 + spacing, sim_size[1]/2 - spacing - 1.5*wg_width - 2*radius1 - gap, 0),
    size = (0,  4 * wg_width, 6 * wg_height)
)

# number of modes to solve
num_modes = 1

# setup and solve for modes
mode_spec = td.ModeSpec(num_modes = num_modes, group_index_step = True, target_neff = 3.48, filter_pol = 'te')
ms = ModeSolver(simulation = sim, plane = source_plane, mode_spec = mode_spec, freqs = [freq0])
mode_data = ms.solve()

print("Effective index of computed modes: ", np.array(mode_data.n_eff))
print("Group index of computed modes: ", np.array(mode_data.n_group))

# visualise the mode
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (15, 5), tight_layout = True)
ms.plot_field("Ex", "real", f = freq0, mode_index = 0, ax = ax1)
ms.plot_field("Ey", "real", f = freq0, mode_index = 0, ax = ax2)
ms.plot_field("Ez", "real", f = freq0, mode_index = 0, ax = ax3)
ax1.set_title("Re{Ex(x, y)}")
ax2.set_title("Re{Ey(x, y)}")
ax3.set_title("Re{Ez(x, y)}")
plt.show()

# add mode source at the input of the waveguide
source_time = td.GaussianPulse(freq0 = freq0, fwidth = 0.5*freqw)
mode_source = ms.to_source(mode_index = 0, direction = "+", source_time = source_time)

sim = sim.copy(update = {"sources" : [mode_source]})
# Out:
# Effective index of computed modes:  [[2.40924144]]
# Group index of computed modes:  [[4.19447207]]

# %% [markdown]
# # Plot Simulation Setup

# %%
fig, ax = plt.subplots(1, 2, tight_layout = True, figsize = (8,4))
sim.plot(x = 0, ax = ax[0]);
sim.plot(z = 0, ax = ax[1]);
plt.show()

# Check probe and source
f, (ax1, ax2) = plt.subplots(1, 2, tight_layout=True, figsize=(8, 4))
plot_time = 0.3e-12
ax1 = sim.sources[0].source_time.plot(times=np.linspace(0, plot_time, 10000), ax=ax1)
ax1.set_xlim(0, plot_time)
ax1.legend(('source amplitude',))
ax2 = sim.sources[0].source_time.plot_spectrum(times=np.linspace(0, sim.run_time, 100000), val = 'abs', ax=ax2)
fill_max = 13e-15
ymax = 14e-15
ax2.fill_between(freq_range, [0,0], [fill_max, fill_max], alpha=0.4, color='g')
ax2.legend(('source spectrum', 'measurement'))
ax2.set_ylim(-1e-16, ymax)
plt.show()

sim.plot_3d()
# Out:
#     <div class="simulation-viewer" data-width="800" data-height="800" data-simulation="{&quot;attrs&quot;: {}, &quot;type&quot;: &quot;Simulation&quot;, &quot;center&quot;: [0.0, 0.0, 0.0], &quot;size&quot;: [13.160000000000002, 11.82, 1.82], &quot;medium&quot;: {&quot;attrs&quot;: {}, &quot;name&quot;: &quot;silica&quot;, &quot;frequency_range&quot;: null, &quot;allow_gain&quot;: false, &quot;nonlinear_spec&quot;: null, &quot;modulation_spec&quot;: null, &quot;heat_spec&quot;: null, &quot;type&quot;: &quot;Medium&quot;, &quot;permittivity&quot;: 2.0852, &quot;conductivity&quot;: 0.0}, &quot;structures&quot;: [{&quot;attrs&quot;: {}, &quot;geometry&quot;: {&quot;attrs&quot;: {}, &quot;type&quot;: &quot;Cylinder&quot;, &quot;axis&quot;: 2, &quot;sidewall_angle&quot;: 0.0, &quot;reference_plane&quot;: &quot;middle&quot;, &quot;radius&quot;: 2.4200000000000004, &quot;center&quot;: [-3.360000000000001, 2.69, 0.0], &quot;length&quot;: 0.22}, &quot;name&quot;: &quot;Outer Ring 1&quot;, &quot;background_permittivity&quot;: null, &quot;background_medium&quot;: null, &quot;type&quot;: &quot;Structure&quot;, &quot;medium&quot;: {&quot;attrs&quot;: {}, &quot;name&quot;: &quot;silicon&quot;, &quot;frequency_range&quot;: null, &quot;allow_gain&quot;: false, &quot;nonlinear_spec&quot;: null, &quot;modulation_spec&quot;: null, &quot;heat_spec&quot;: null, &quot;type&quot;: &quot;Medium&quot;, &quot;permittivity&quot;: 12.085, &quot;conductivity&quot;: 0.0}}, {&quot;attrs&quot;: {}, &quot;geometry&quot;: {&quot;attrs&quot;: {}, &quot;type&quot;: &quot;Cylinder&quot;, &quot;axis&quot;: 2, &quot;sidewall_angle&quot;: 0.0, &quot;reference_plane&quot;: &quot;middle&quot;, &quot;radius&quot;: 1.9800000000000002, &quot;center&quot;: [-3.360000000000001, 2.69, 0.0], &quot;length&quot;: 0.22}, &quot;name&quot;: &quot;Inner Ring 1&quot;, &quot;background_permittivity&quot;: null, &quot;background_medium&quot;: null, &quot;type&quot;: &quot;Structure&quot;, &quot;medium&quot;: {&quot;attrs&quot;: {}, &quot;name&quot;: &quot;silica&quot;, &quot;frequency_range&quot;: null, &quot;allow_gain&quot;: false, &quot;nonlinear_spec&quot;: null, &quot;modulation_spec&quot;: null, &quot;heat_spec&quot;: null, &quot;type&quot;: &quot;Medium&quot;, &quot;permittivity&quot;: 2.0852, &quot;conductivity&quot;: 0.0}}, {&quot;attrs&quot;: {}, &quot;geometry&quot;: {&quot;attrs&quot;: {}, &quot;type&quot;: &quot;Cylinder&quot;, &quot;axis&quot;: 2, &quot;sidewall_angle&quot;: 0.0, &quot;reference_plane&quot;: &quot;middle&quot;, &quot;radius&quot;: 2.3200000000000003, &quot;center&quot;: [-3.4600000000000013, -2.79, 0.0], &quot;length&quot;: 0.22}, &quot;name&quot;: &quot;Outer Ring 2&quot;, &quot;background_permittivity&quot;: null, &quot;background_medium&quot;: null, &quot;type&quot;: &quot;Structure&quot;, &quot;medium&quot;: {&quot;attrs&quot;: {}, &quot;name&quot;: &quot;silicon&quot;, &quot;frequency_range&quot;: null, &quot;allow_gain&quot;: false, &quot;nonlinear_spec&quot;: null, &quot;modulation_spec&quot;: null, &quot;heat_spec&quot;: null, &quot;type&quot;: &quot;Medium&quot;, &quot;permittivity&quot;: 12.085, &quot;conductivity&quot;: 0.0}}, {&quot;attrs&quot;: {}, &quot;geometry&quot;: {&quot;attrs&quot;: {}, &quot;type&quot;: &quot;Cylinder&quot;, &quot;axis&quot;: 2, &quot;sidewall_angle&quot;: 0.0, &quot;reference_plane&quot;: &quot;middle&quot;, &quot;radius&quot;: 1.8800000000000001, &quot;center&quot;: [-3.4600000000000013, -2.79, 0.0], &quot;length&quot;: 0.22}, &quot;name&quot;: &quot;Inner Ring 2&quot;, &quot;background_permittivity&quot;: null, &quot;background_medium&quot;: null, &quot;type&quot;: &quot;Structure&quot;, &quot;medium&quot;: {&quot;attrs&quot;: {}, &quot;name&quot;: &quot;silica&quot;, &quot;frequency_range&quot;: null, &quot;allow_gain&quot;: false, &quot;nonlinear_spec&quot;: null, &quot;modulation_spec&quot;: null, &quot;heat_spec&quot;: null, &quot;type&quot;: &quot;Medium&quot;, &quot;permittivity&quot;: 2.0852, &quot;conduct ...

# %%
# initializes job, puts task on server (but doesnt run it)
job = web.Job(simulation=sim, task_name="quad", verbose=True)

# estimate the maximum cost
estimated_cost = web.estimate_cost(job.task_id)
# Out:
# 14:29:52 GMT Standard Time WARNING: Simulation has 1.26e+06 time steps. The
#                            'run_time' may be unnecessarily large, unless there
#                            are very long-lived resonances.
#                            Created task 'quad' with task_id
#                            'fdve-d589cc57-12c2-48a4-b76c-f717266273e8' and
#                            task_type 'FDTD'.
#                            View task using web UI at
#                            ]8;id=601774;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d589cc57-12c2-48a4-b76c-f717266273e8\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=165878;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d589cc57-12c2-48a4-b76c-f717266273e8\taskId]8;;\]8;id=601774;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d589cc57-12c2-48a4-b76c-f717266273e8\=]8;;\]8;id=736244;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d589cc57-12c2-48a4-b76c-f717266273e8\fdv]8;;\
#                            ]8;id=736244;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d589cc57-12c2-48a4-b76c-f717266273e8\e]8;;\]8;id=601774;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d589cc57-12c2-48a4-b76c-f717266273e8\-d589cc57-12c2-48a4-b76c-f717266273e8']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 14:29:55 GMT Standard Time Maximum FlexCredit cost: 4.638. Minimum cost depends
#                            on task execution details. Use
#                            'web.real_cost(task_id)' to get the billed FlexCredit
#                            cost after a simulation run.

# %%
sim_data = job.run(path="data/microring_baseline.hdf5")
# Out:
# 14:29:59 GMT Standard Time status = queued
#                            To cancel the simulation, use 'web.abort(task_id)' or
#                            'web.delete(task_id)' or abort/delete the task in the
#                            web UI. Terminating the Python script will not stop
#                            the job running on the cloud.
# Output()
# 14:30:04 GMT Standard Time status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 14:30:08 GMT Standard Time Maximum FlexCredit cost: 4.638. Use
#                            'web.real_cost(task_id)' to get the billed FlexCredit
#                            cost after a simulation run.
#                            starting up solver
#                            running solver
# Output()
# 14:49:57 GMT Standard Time early shutoff detected at 96%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 14:49:58 GMT Standard Time status = postprocess
# Output()
# 14:50:02 GMT Standard Time status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 14:50:03 GMT Standard Time View simulation result at
#                            ]8;id=239083;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d589cc57-12c2-48a4-b76c-f717266273e8\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=911028;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d589cc57-12c2-48a4-b76c-f717266273e8\taskId]8;;\]8;id=239083;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d589cc57-12c2-48a4-b76c-f717266273e8\=]8;;\]8;id=82406;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d589cc57-12c2-48a4-b76c-f717266273e8\fdv]8;;\
#                            ]8;id=82406;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d589cc57-12c2-48a4-b76c-f717266273e8\e]8;;\]8;id=239083;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d589cc57-12c2-48a4-b76c-f717266273e8\-d589cc57-12c2-48a4-b76c-f717266273e8']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 14:50:23 GMT Standard Time loading simulation from data/microring_baseline.hdf5

# %%
T1 = sim_data["Flux Monitor (Through Port)"].flux
T2 = sim_data["Flux Monitor (Drop Port 1)"].flux
T3 = sim_data["Flux Monitor (Drop Port 2)"].flux
T4 = sim_data["Flux Monitor (Drop Port 3)"].flux
T5 = sim_data["Flux Monitor (Drop Port 4)"].flux
measured_f = sim_data["Flux Monitor (Through Port)"].flux.f

plt.plot(td.C_0 / measured_f, T1, "red", linewidth=2)
plt.xlabel("Wavelength ($\mu m$)")
plt.ylabel("Through Port")
plt.show()

plt.plot(td.C_0 / measured_f, T2, "red", linewidth=2)
plt.xlabel("Wavelength ($\mu m$)")
plt.ylabel("Drop Port 1")
plt.show()

plt.plot(td.C_0 / measured_f, T3, "red", linewidth=2)
plt.xlabel("Wavelength ($\mu m$)")
plt.ylabel("Drop Port 2")
plt.show()

plt.plot(td.C_0 / measured_f, T4, "red", linewidth=2)
plt.xlabel("Wavelength ($\mu m$)")
plt.ylabel("Drop Port 3")
plt.show()

plt.plot(td.C_0 / measured_f, T5, "red", linewidth=2)
plt.xlabel("Wavelength ($\mu m$)")
plt.ylabel("Drop Port 4")
plt.show()
